# %% [markdown]
# # play with boolean values

# %% [markdown]
# Try these:

# %%
False | False, True or True, True or False, False or True

# %%
False and False, True & True, True & False, False & True

# %%
False & True

# %%
not True

# %%
not False

# %% [markdown]
# ## not operator

# %%
not False

# %%
f = False
not f

# %%
not True

# %%
t = True
not t

# %% [markdown]
# ## or operator

# %%
True or False

# %%
True | False

# %%
True or True

# %%
True | True

# %%
False or True

# %%
False | True

# %%
False or False

# %%
False | False

# %% [markdown]
# ## and operator

# %%
True and False

# %%
True and True

# %%
False and True

# %%
False and False

# %%
True & False

# %%
True & True

# %%
False & True

# %%
False & False

# %% [markdown]
# ## combining not, or operators

# %%
not (not (True or False))

# %%
not (True or True)

# %%
not (False or True)

# %%
not (False or False)

# %% [markdown]
# ## combining not, and operators

# %%
not (True)

# %%
not (True and False)

# %%
not (True and True)

# %%
not (False and True)

# %%
not (False and False)

# %% [markdown]
# ## equality operator

# %%
# assign 2 to variable x
x = 2
x

# %%
# check if x has value of 2
x == 2

# %%
3 == 2

# %%
2 == 2

# %%
2 == 3

# %% [markdown]
# ### equality operator:   variables on one side or both sides

# %%
share_52_wk_high = 3200
today_share_price = 3200
today_share_price == share_52_wk_high

# %%
today_share_price == 3200

# %%
# avoid this, as convention
3200 == today_share_price

# %%
share_52_wk_high = 3200
share_52_wk_low = 2000
today_share_price = 2000
today_share_price == share_52_wk_high

# %%
n = 20
# this is not normally used by it is still legal
20 == n
# if there is a variable and value in such an operation, variable is on the left side
# correct way
n == 20

# %% [markdown]
# ## not equal operator

# %%
5 >= 4

# %%
5 != 4

# %%
5 != 5

# %% [markdown]
# ### using variables and values

# %%
# Olympic champion Neeraj Chopra throws Javelin 89.3 m in a practice session
# he held the previous national record of 88.07m
last_throw =89.3
national_record = 88.07

# check if his last throw matched his previous record
last_throw >= national_record

# %% [markdown]
# ## scenarion exercise: use equality operator in KYC

# %%
# Try this. 
# Create variable to store the customer name as written in the form. 
# Create another variable for name as in Aadhar card
# compare them using equality operator as part an imaginary KYC process

# %%
name_in_form = "Sri Krishna"
name_in_aadhar = "sri krishna"
name_in_aadhar == name_in_form

# %%
name_in_form = "Sri Krishna"
name_in_aadhar = "Srikrishna" 
# kyc step
name_in_form == name_in_aadhar

# %%
# try editing the texts using upper case, lower case, space, a minor type where you use 0 instead of O

# %%
# try these
name_in_form = "sri krishna"
name_in_aadhar = "srikrishna" 
# kyc step
name_in_form == name_in_aadhar
# Out:
# False

# %% [markdown]
# #### if a string value is created using double quotes and the same value with single quotes, are they equal?

# %%
name_in_form = 'Srikrishna'
name_in_aadhar = "Srikrishna" 
# kyc step
name_in_form == name_in_aadhar

# %% [markdown]
# ## operators for greater than, less than, greater than or equal to, less than or equal to

# %%
# Olympic champion Neeraj Chopra throws Javelin 89.3 m in a practice session
# he held the previous national record of 88.07m
# check if his last throw beat his previous record
last_throw =89.3
national_record = 88.07

last_throw > national_record

# %%
# create a variable for admission cut_off in Delhi University i.e. if a student scores cut-off or more
# then student is eligible for the admission
cut_off = 95
# create a three variables to hold marks of three different students
marks_A = 96
marks_B = 95
marks_C = 75
# check if each student is eligible or not
marks_A >= cut_off, marks_B >= cut_off, marks_C >= cut_off
# Out:
# (True, True, False)

# %%
# Banks approve loans if the EMI due is less than half of the applicant's take home salary per month
# create a variable for take home salary
take_home_salary = 100
# create a variable for EMI
EMI_due = 55

# check if the applicant can be granted the loan
EMI_due < take_home_salary * 0.5
# Out:
# False

# %% [markdown]
# # IF statement

# %%
marks = 85
if (marks < 40):
    print("Fail")
else:
    if marks >= 60:
        print("first")
    else:
        print("Pass")
# Out:
# first

# %%
x = 1
if (x>=3):
    print('is equal or greater than 3')
else:
    print('is less than 3')
# Out:
# is less than 3

# %%
take_home_pay = 100
EMI = 48
if (EMI < 0.5 * take_home_pay):
    print('loan can be approved')
else:
    print('loan cannot be approved')
# Out:
# loan can be approved

# %%
marks = 99
cutoff = 98
if (marks >= cutoff):
    print('congrats! admitted to the course')
else:
    print('sorry! not admitted to the course')
# Out:
# congrats! admitted to the course

# %%
x = 1
if (x>=3):
    print('is equal or greater than 3')
    print("this will show only in if path")
else:
    print("this will show only in else path")
    print('is less than 3')
# Out:
# this will show only in else path
# is less than 3

# %%
# create variables for height in m and weight in kgs
# calculate bmi and store it in a new variable
# compare this bmi with the cut-offs for underweight, normal, overweight, obese
#BMI=(Weight(kg)/height(m)**2)

Wt=float(input("Kinly enter your wt in kg's:- "))
ht=float(input("Kinly enter your ht in mt's:- "))

BMI = (Wt/(ht**2))
print(BMI)

if (BMI >=40):
    print('You have obesity 3')

elif (BMI <40 and BMI >=35):
    print('You have obesity 2')

elif (BMI <35 and BMI >=30):
    print('You have obesity 1')
    
elif (BMI <30 and BMI >=25):
    print('You are Overweight')

elif (BMI <25 and BMI >=18.5):
    print('You Normal(Healthy)')

else:
    print("You are UnderWeight")
# Out:
# 24.27012471655329
# You Normal(Healthy)

# %%
# typically pass marks in exams are 40. therefore if a student score 39 or less, the result is fail
# create three variables for storing three students' marks
# check each if it is 39 or less

marks_A = 90
marks_B = 75
marks_C = 25

# check result of A
print("A")
if (marks_A >= 40):
    print("Pass")
else:
    print('Fail')

# check result of B
print("B")
if (marks_B < 40):
    print('Fail')
else:
    print('Pass')

# check result of C
print("C")
if (marks_C <= 39):
    print('Fail')
else:
    print('Pass')
# Out:
# A
# Pass
# B
# Pass
# C
# Fail

# %%
# writing the same check in different ways
# consider the previous exercise related to pass marks of 40.
# create a variable to store marks, say the student scored 78
# we can test for Fail result using <= 39
# or Fail result as < 40

Maths = 98
Python =99
SQL = 97
Pass =40

if Maths>=Pass:
    print(f"you got {Maths} marks in Maths and you are pass")
else:
    print('fail')
# Out:
# you got 98 marks in Maths and you are pass

# %%
# Even numbers are divisible by 2. This means the remainder from a division by 2 is zero.
# create a variable to hold a number. how can we check if this number is an even number?

num =int(input("Enter number to check whether the number is even or odd:-"))

if (num %2 ==0):
    print('You entered the even number')
else:
    print('You entered the odd number')
# Out:
# You entered the odd number

# %%
# create a variable to hold a number
# can you check if this number is divisible by 7?
num =int(input("Enter number to check whether the number is even or odd:-"))

if (num %7 ==0):
    print('Yeah! the number is divisible by 7')
else:
    print('No the number is not divisble by 7')
# Out:
# No the number is not divisble by 7

# %%
# we saw that there may be more than one way of expressing a statement
# if there is a variable and we want to check of its value equals a number, say 7, we can use var == 7
# are there other ways of stating this?

# %%
# create the variable and assign 
var = 8
not ((var < 7) or (var > 7))
# Out:
# False

# %%
# in the earlier exercises, we focused on evaluating boolean expressions as True or False.
# the IF statement uses this to decide the next lines to execute

# %%
marks = 78
if (marks >= 40):
    print("Pass")
# Out:
# Pass

# %%
marks = 78
result = ""

if (marks < 40):
    result = "Fail"
else:
    result = "Pass"

print(result)
# Out:
# Pass

# %%
# there is one more way of writing this

marks = 78
result = ""

if (marks < 40):
    result = "Fail"

if (marks >= 40):
    result = "Pass"
    
print(result)
# Out:
# Pass

# %%
# in universities, the following classifications are used: < 40 Fail, 40-59 is Pass, 60-74 First Class
# 75 or more is Distinction
# can you implement this as a series of if statements?
marks =75

'''
This is wrong as it will check for each statement either it is fullfilled then also it will execute another
if (marks <40):
    print('Fail')
if (marks >=40 and marks <=59):
    print('Pass')
if (marks >=60 and marks <=74):
    print('First Class')
if (marks >75):
    print('Distinction')

'''
if (marks <40):
    print('Fail')
elif (marks >=40 and marks <=59):
    print('Pass')
elif (marks >=60 and marks <=74):
    print('First Class')
else:
    print('Distinction')
# Out:
# Distinction

# %%
# Exercise
# can you write interpretation of BMI as a series of if statements?

# %%
weight = float(input("Enter weight in Kgs: "))
height = float(input("Enter height in cm: "))
ht_in_meters = height / 100
BMI = weight / (ht_in_meters **2)
print(BMI)

if (BMI < 18.4):
    print("under weight")
elif (BMI <= 24.9):
    print("normal")
elif (BMI <= 29.9):
    print("overweight")
else:
    print("obese")

# %%
bmi = 29.1
bmi > 29 and bmi < 29.2

# %%
# social media applications recommend new users to connect with. 
# For e.g. LinkedIn suggests new connections.
# an imaginary social media app considers users as teens and adults
# compares their base country
# if there is a match of both then makes recommendations
# create variables for two users: their age, their country
# compare them and if there is a match, print the result

user1 = ("Teen" if 16 < 18 else "Adult", "India")
user2 = ("Teen" if 17 < 18 else "Adult", "India")

if user1 == user2:
    print("Recommendation: Connect these users!")
else:
    print("No recommendation.")
# Out:
# Recommendation: Connect these users!

# %% [markdown]
# *
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *

# %%
# user 1
age_1 = 20
country_1 = "India"
# user 2
age_2 = 23
country_2 = "India"

score = 0
if (age_1 < 13) or (age_2 < 13):
    score = -1
# check if users are in same age group
elif (age_1 < 18) and (age_2 < 18):
    score = score + 1
elif (age_1 >= 18) and (age_2 >= 18):
    score = score + 1

if (country_1 == country_2):
    score = score + 1

print(score)

if score==2:
    print("Recommendation: Connect these users!")
else:
    print("No recommendation.")
# Out:
# 2
# Recommendation: Connect these users!

# %%
# user 1
age_1 = 20
country_1 = "India"
# user 2
age_2 = 23
country_2 = "India"

if ((country_1 == country_2) and (age_1 < 18) and (age_2 < 18)):
    print("match")
elif (country_1 == country_2) and (age_1 >= 18) and (age_2 >= 18):
   print("match")
else:
    print("no match")
# Out:
# match

# %%
# user 1
age_1 = 15
country_1 = "India"
# user 2
age_2 = 23
country_2 = "India"

# check if users are in same age group
score = 0
if (age_1 < 20) and (age_2 < 20):
    score = score + 1
if (age_1 >= 20) and (age_2 >= 20):
    score = score + 1
if (country_1 == country_2):
    score = score + 1

if score < 0:
    print("underage")
elif score <= 1:
    print("no match")
elif (score == 2):
    print("match")

# %%
# what will be the result of this statement?

if (True):
    print("Hello")
else:
    print("Hi")
# Out:
# Hello

# %%
# short version of if statement

# %%
num = 4
if num > 0: print("it is a positive number")
# Out:
# it is a positive number

# %%
# short version of else statement
num = 4
print("negative") if num <= 0 else print("it is a positive number")
# Out:
# it is a positive number

# %%
# these are not recommended. just for awareness.
# more compact conditional statements

# %%
marks = 10
"pass" if marks >= 39 else "fail"
# Out:
# 'fail'

# %%
x = 5 if x == 0 else 5

# %%
x
# Out:
# 5

# %%
# input from user
print('Enter your name:')
x = input()
print('Hello, ' + x)
# Out:
# Enter your name:
# Hello, Chiru

# %%
# Exercise:
# A country set up this protocol for their spies. Their field agents will call a toll free number.
# They will get a harmless voice message that says it is The Nowhere Travel company and asks them to leave a message.
# In response the caller states their passcode.
# if the passcode is a valid one, a human operator comes online and greets them with their name
# In this elite team, there are only three agents alive now. Imagine names, passcodes and implement this.
# use only if statements
ag_res='12345'
ag1={"name":"Chirag","passcode" :'!@#$%^'}
ag2={"name":"Aayush","passcode" :'12345'}
ag3={"name":"Mredhul","passcode" :'67890'}

if ag_res == ag1['passcode'] :
    print(f'Hi,{ag1["name"]}')
if ag_res == ag2['passcode'] :
    print(f'Hi,{ag2['name']}')
if ag_res == ag3['passcode'] :
    print(f'Hi,{ag3['name']}')
# Out:
# Hi,Aayush

# %%
ag_res = '12345'

agents = {
    "!@#$%^": "Chirag",
    "12345": "Aayush",
    "67890": "Mredhul"
}

if ag_res in agents:
    print(f'Hi, {agents[ag_res]}')
# Out:
# Hi, Aayush

# %%
# Exercise:
# implement the previous scenario using if-elif statements
ag_res='1234345'
ag1={"name":"Chirag","passcode" :'!@#$%^'}
ag2={"name":"Aayush","passcode" :'12345'}
ag3={"name":"Mredhul","passcode" :'67890'}

if ag_res == ag1['passcode'] :
    print(f'Hi,{ag1["name"]}')
elif ag_res == ag2['passcode'] :
    print(f'Hi,{ag2['name']}')
elif ag_res == ag3['passcode'] :
    print(f'Hi,{ag3['name']}')
else:
    print('Invalid Response')
# Out:
# Invalid Response

# %%
#Exercise: 
# ask for sunsign from user, based on the input print one line prediction for the day
predictions = {
    "Aries": "Today is a good day for new beginnings.",
    "Taurus": "Focus on stability and practical matters.",
    "Gemini": "Communication will bring you opportunities.",
    "Cancer": "Family and emotions take center stage today.",
    "Leo": "Your leadership qualities will shine.",
    "Virgo": "Pay attention to details and health.",
    "Libra": "Balance and harmony guide your decisions.",
    "Scorpio": "Transformation and deep thinking are powerful today.",
    "Sagittarius": "Adventure and learning will inspire you.",
    "Capricorn": "Hard work and discipline will pay off.",
    "Aquarius": "Innovation and friendships bring joy.",
    "Pisces": "Creativity and intuition are strong today."
}

sunsign=input("Enter your Sunsign Here:-")
sunsign=sunsign.capitalize()
# print(sunsign)
if sunsign in predictions:
    print(predictions[sunsign])
else:
    print("There is no such sunsign")
# Out:
# Hard work and discipline will pay off.

# %%
# Exercise:
# there are two people and we know their ages.
# print out the older person's age

# %%
A = 20
B = 25
if (A > B):
    print("A is older person :", A)
else:
    print("B is older person :", B)

# %%
# contd: how will you handle the previous scenario if there are three people?
# what is the oldest person's age?

A = 1
B = 3
C = 4

if (A > B):
    if (A > C):
        print("A is older person :", A)
    else:
        print("C is the oldest ", C)
else:
    if (B > C):
        print("B is oldest person :", B)
    else:
        print("C is oldest person :", C)
# Out:
# C is oldest person : 4

# %%
# contd: how will you handle the sam scenario if there are four people?
A = 1
B = 3
C = 4
D = 5

if (A > B) and (A>C) and (A>D):
    print('A is the oldest',A)

elif (B > A) and (B>C) and (B>D):
    print("B is the oldest ", B)     

elif (C > A) and (C>B) and (C>D):
    print("C is the oldest ", C)    
else:
    print("D is oldest person :", D)
# Out:
# D is oldest person : 5

# %%
#Exercise:
# investment managers suggest that we should maintain a portfolio that is diversified. The general formula is 10% in Gold
# (100 - age)% in equity and remaining in debt
# ask user for their age and print the recommended portfolio composition

age =int(input('Enter your age to check the recommended portfolio composition'))
Equity = (100-age)
Debt= 100-10-Equity
print (f'You should invest 10% in Gold,{Equity}% in Equity and {Debt}% in Debt ')
# Out:
# You should invest 10% in Gold,75% in Equity and 15% in Debt

# %%
age = 25
gold = 10
equity = 100 - age
debt = 100 - gold - equity
print("Gold: ", gold,"%")
print("equity: ", equity, "%")
print("Debt: ",debt, "%")

# %%
# Exercise:
# a restaurant asks customer for rating on each of ambience, food, and service
# customer enters a rating 8 to 10 they are satisfied 6-7 is neutral and lesser rating is dissatisfied
# in the end, print a summary like: you were satisfied with our food and ambience but neutral on service


# how to implement:
# ask for rating using three input statements
# using if-elif generate the output

# %%
ambience = 5
food = 7
service = 10

if ambience >= 8:
    print("you are happy with ambience")
elif ambience >= 6:
    print("you are neutral with ambience")
else:
    print("you are not happy with ambience")

if food >= 8:
    print("you are happy with food")
elif food >= 6:
    print("you are neutral with food")
else:
    print("you are not happy with food")

if service >= 8:
    print("you are happy with service")
elif service >= 6:
    print("you are neutral with service")
else:
    print("you are not happy with service")

# %%
def feedback(rating, aspect):
    if rating >= 8:
        return f"You were satisfied with our {aspect}"
    elif rating >= 6:
        return f"You were neutral on {aspect}"
    else:
        return f"You were dissatisfied with our {aspect}"

ambience = 5
food = 7
service = 10

print(feedback(ambience, "ambience"))
print(feedback(food, "food"))
print(feedback(service, "service"))
# Out:
# You were dissatisfied with our ambience
# You were neutral on food
# You were satisfied with our service

# %%
# Exercise:
# Did you know that nearly 90% of all trades in stock exchanges algorithmic trades?
# One of the popular types of trades is Arbitrage Trade.
# Example: If TCS sells at 3000 in NSE and 2998 in BSE then arbitrage traders buy from it BSE and sell at NSE and make 2 Rs profit
# In this scenario, we are focused on TCS price in two exchanges: NSE, BSE
# Consider the prices and decide on the trade as Buy from *SE and sell in *SE and also print the potential profit.
# if the difference is less than 1% of the share price it is not worth the cost of conducting the trade 
# so you take in price in BSE and NSE, and the output is "Buy from ": *SE, 'Sell at ': *SE and profit of x Rs per share
# or just 'No trade'

NSE =int(input('Enter the Price of TCS in NSE'))
BSE =int(input('Enter the Price of TCS in BSE'))


if BSE>NSE:
    profit = ((BSE-NSE)/NSE)*100
    if profit > 1:
        print(f"Buy from NSE at {NSE} and sell to BSE at {BSE} and your profit% is {profit}")

    else:
        print("No need to trade")

else:
    profit = ((NSE-BSE)/BSE)*100
    if profit > 1:
        print(f"Buy from BSE at {BSE} and sell to NSE at {NSE} and your profit% is {profit}")
    else:
        print("No need to trade")
# Out:
# Buy from NSE at 2000 and sell to BSE at 2200 and your profit% is 10.0

# %%
# Exercise:
# Students are eligible for taking exams if their attendance is at least 75%
# take the total number of classes conducted and the attendance of a student
# if less than cut-off but the student has an exception appoved by the Principal then they are allowed.
# Else permission is denied

# %%
present = 20
classes = 30
attendance = present / classes

approval = "Yes"

if attendance >= 0.75:
    print("Eligible")
elif approval == "Yes":
    print("Eligible")
else:
    print('Not eligible')
# Out:
# Eligible

# %%
# Exercise:
# a company asks their employees to go thru periodic medical tests and you are asked to handle this scenario.
# You may recall BP has two readings. Systolic and Diastolic. Following are criteria for systolic reading.
# Normal: Below 120
# Elevated: 120-129
# Stage 1 high blood pressure (also called hypertension): 130-139
# Stage 2 hypertension: 140 or more
# Call for help: 180 or more.

systolic = 145  

if systolic < 120:
    print("Normal")
elif systolic >= 120 and systolic <= 129:
    print("Elevated")
elif systolic >= 130 and systolic <= 139:
    print("Stage 1 Hypertension")
elif systolic >= 140 and systolic < 180:
    print("Stage 2 Hypertension")
else:  # systolic >= 180
    print("Call for help")
# Out:
# Stage 2 Hypertension

# %%
# Exercise:
# Regarding the diastolic blood pressure:
#Normal: Lower than 80
#Stage 1 hypertension: 80-89
#Stage 2 hypertension: 90 or more
# Call for help: 120 or more.
diastolic = 95  

if diastolic < 80:
    print("Normal")
elif diastolic >= 80 and diastolic <= 89:
    print("Stage 1 Hypertension")
elif diastolic >= 90 and diastolic < 120:
    print("Stage 2 Hypertension")
else:  # diastolic >= 120
    print("Call for help")
# Out:
# Stage 2 Hypertension

# %%
# Exercise:
# Combine the previous two exercises and rate a patient using both Systolic and Diastolic readings

# Example readings
systolic = 145
# diastolic = 95

# Classify systolic
if systolic < 120 or diastolic < 80:
    sys_status = "Normal"
elif systolic <= 129 :
    sys_status = "Elevated"
elif systolic <= 139 or diastolic <= 89:
    sys_status = "Stage 1 Hypertension"
elif systolic < 180 or diastolic < 120:
    sys_status = "Stage 2 Hypertension"
else:
    sys_status = "Call for help"

# Print combined result
print(f"Systolic: {sys_status}, Diastolic: {sys_status}")
# Out:
# Systolic: Stage 2 Hypertension, Diastolic: Stage 2 Hypertension

# %%
# Delhi university announces cut-offs for admission eligibility. An innovative approach was followed. For each XII board they
# selected a cut-off reflecting the performance levels for that year. For example: CBSE 95%, ICSE 93%, StateBoard 96%,..
# You take the board and actual marks for a student and respond with a message on their eligibility.# Cut-off marks for each board
cutoffs = {
    "CBSE": 95,
    "ICSE": 93,
    "StateBoard": 96
}

# Example student input
board = "ICSE"
marks = 94

# Check eligibility
if board in cutoffs:
    if marks >= cutoffs[board]:
        print(f"Eligible: Your marks {marks}% meet the {board} cut-off of {cutoffs[board]}%.")
    else:
        print(f"Not Eligible: Your marks {marks}% are below the {board} cut-off of {cutoffs[board]}%.")
else:
    print("Board not recognized.")
# Out:
# Eligible: Your marks 94% meet the ICSE cut-off of 93%.

# %%
# class discussion

# %%
x = -4
y = 3
if (x + y > 0):
    print(x)
    print(y)

# %%
x = -1
if (x >= 0):
    if (x==0):
        print("zero")
    else:
        print("positive")
else:
    print("negative")
# Out:
# negative

# %%
marks = 80
if (marks >= 75):
    print("distinction")
elif (marks >=60):
    print("first class")
elif (marks >=40):
    print("pass")
else:
    print("fail")
# Out:
# distinction

# %%
marks = 60
if (marks >= 75):
    print("distinction")
elif (marks >=40):
    print("pass")
elif (marks >=60):
    print("first class")
else:
    print("fail")
# Out:
# pass

# %%
pressed_number = 1

if (pressed_number == 1):
    print("you selected English")
elif (marks >=60):
    print("first class")
elif (marks >=40):
    print("pass")
else:
    print("fail")
# Out:
# you selected English

# %%
x = input('Enter a number:')
print(x)
print(type(x))
# Out:
# 342
# <class 'str'>

# %%
print('Hello, ' + x)
# Out:
# Hello, 342

# %% [markdown]
# write operators similar names
# ==
# <
# >
# <=
# >=

# %%
Marks ={'pass' :40,
        'first' :60,
        'Distinction':75,
        'Nerd ':90}
for key,value in Marks.items():
    if (value == 60):
        print(key)
# Out:
# first

# %%
marks =85
if (marks >90):
    print('Nerd')
elif (marks >75):
    print('Distinction')
elif(marks >60):
    print('Pass')
else:
    print('fail')
# Out:
# Distinction
