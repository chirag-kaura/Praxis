# %% [markdown]
# **hello world**
#
#
# can add more text

# %%
# place cursor in the cell below and click Run

#sure, here too

# %%
print('Hello world')
# Out:
# Hello world

# %%
# run this cell using "Shift + Enter"
print("this is fun")
# Out:
# this is fun

# %%
# try "Ctrl + Enter"
print("this is fun")
# Out:
# this is fun

# %%
# backslash is used to create escape sequences i.e. it escapes the usual and does something else
# \n is used to add a new line.
# \t is used to add a tab
# \\ is used to include \ as part of folder path (we will see this later in the course)

# %%
print("Hello world", "\n", "this is fun") # notice the "\n" newline character
# Out:
# Hello world
#  this is fun

# %%
# default
print("hello","world")
# Out:
# hello world

# %%
# print without sep
print("hello", "world", sep='$')
# Out:
# hello$world

# %%
# prints 
print("hello \n") # in print, there is end="\n"
print("world")
# Out:
# hello
#
# world

# %%
# prints 
print("hello", end=" ") # modified end with a null string
print("world1", end=":-)")
print("world2")
# Out:
# hello world1:-)world2

# %%
# tab character
print("Hello world", "\t", "this is fun")
# Out:
# Hello world 	 this is fun

# %%
25**2
# Out:
# 625

# %%
# using calculations in a print
print("I took two numbers and added them. I got this :", 5+6)
# Out:
# I took two numbers and added them. I got this : 11

# %%
# more operators: modulus operation returns the remainder
7 % 5
# Out:
# 2

# %%
# quotient
7 // 5
# Out:
# 1

# %%
print("The modulus operation returns the reminder ", 18 % 5)
# Out:
# The modulus operation returns the reminder  3

# %%
print("ABC" , "abc"), print("ABC" + "abc")
# Out:
# ABC abc
# ABCabc
# (None, None)

# %%
print("how is this session?" + " is it fun?")
# Out:
# how is this session? is it fun?

# %%
"hello" + " " + "world"
# Out:
# 'hello world'

# %%
print ("hello")
# Out:
# hello

# %% [markdown]
# ## values and variables

# %% [markdown]
# ### create variables

# %%
x = 11
y = 2
x + y
# Out:
# 13

# %%
y = 2
type(y)
# Out:
# int

# %%
print(x)
print(y)
# Out:
# 11
# 2

# %%
# this creates a variable with the given name, assigns an integer type value
count_of_pens = 120.0

# %%
print(count_of_pens)
# Out:
# 120.0

# %%
# check the type
type(count_of_pens)
# Out:
# float

# %%
count_of_pens * 2
# Out:
# 240

# %%
# create a new float type variable
pens_weight = 1.5

# %%
type(pens_weight)
# Out:
# float

# %%
type("a"), type(1), type(1.1)
# Out:
# (str, int, float)

# %%
# create a new string variable
greetings = "hello world"
greetings
# Out:
# 'hello world'

# %%
type(greetings), type("hello world")
# Out:
# (str, str)

# %%
# string can be created using single or double quotes
greetings = 'hello world'
greetings
# Out:
# 'hello world'

# %%
"ABC" + 'abc' + 'aBc"
# Out:
#   Cell In[41], line 1
#     "ABC" + 'abc' + 'aBc"
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"ABC" + 'abc' + "aBc"
# Out:
# 'ABCabcaBc'

# %%
x > y, x == y, x < y, x >= y , x <= y
# Out:
# (True, False, False, True, False)

# %%
# create a new boolean variable
check = (5 > 3)
check
# Out:
# True

# %%
type(check)
# Out:
# bool

# %%
check = (5 < 3)
check
# Out:
# False

# %%
type(check)
# Out:
# bool

# %%
check = False
type(check)
# Out:
# bool

# %%
boolean = True
type(boolean)
# Out:
# bool

# %%
# there are two ways of displaying values in the variables
count_of_pens
# Out:
# 120

# %%
print(count_of_pens)
# Out:
# 120

# %%
x = 1
y = 2
print(x)
print(y)
# Out:
# 1
# 2

# %%
# combine variables in same print 
print("There were ", count_of_pens, " in the store. They weigh ", pens_weight, " kgs")
# Out:
# There were  120  in the store. They weigh  1.5  kgs

# %%
# displaying string variable
lang_name = "Python"
print(lang_name, "is a fun language to learn")
# Out:
# Python is a fun language to learn

# %%
# displaying boolean variable
marks = 95
results =  (marks >= 40)
print(results)
# Out:
# True

# %%
# difference between equality "==" and assignment "=" operators

# when we want to assign a value to a variable, = is used
# when we want to compare two variables / values, == is used

# assign value to a variable 
temperature = 30
day = "Tuesday"
having_fun = True

temperature,day,having_fun
# Out:
# (30, 'Tuesday', True)

# %%
# the == operator compares two variables / values and returns a bolean
temperature == 30
# Out:
# True

# %%
day == 'Friday'
# Out:
# False

# %%
maths = 100
physics = 98
chemistry = 99
biology = 95
english = 87
total_marks = maths + physics + chemistry + biology + english
total_marks
# Out:
# 479

# %%
sales = 4500
cost = 3500
profit = sales - cost
profit
# Out:
# 1000

# %%
unit_price = 4.2
qty = 120
total_amount = unit_price * qty
print(total_amount)
# Out:
# 504.0

# %%
profit = 1000
shares = 200
profit_per_share = profit / shares
print(profit_per_share)
# Out:
# 5.0

# %%
profitable = (sales > cost)
profitable
# Out:
# True

# %%
# did the student get full marks in maths?
maths == 100
# Out:
# True

# %%
# quotient, remainder

# four friends ate lunch and decided to split the bill
bill_amount = 127
people = 4
bill_amount/people
# Out:
# 31.75

# %%
bill_amount//people # quotient
# Out:
# 31

# %%
bill_amount % people # remainder
# Out:
# 3

# %%
# power operator **
5**2

# %% [markdown]
# ### avoid the reserved keywords as names of variables

# %% [markdown]
# Python has a set of keywords that are reserved words that cannot be used as variable names, function names, or any other identifiers
#
# a list can be seen in
#
# https://www.w3schools.com/python/python_ref_keywords.asp

# %%
# True and False are keywords.
True = 2
# Out:
#   Cell In[50], line 2
#     True = 2
#     ^
# SyntaxError: cannot assign to True

# %%
for = 3
# Out:
#   Cell In[2], line 1
#     for = 3
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### order of operation: PEMDAS

# %% [markdown]
# (paranthesis exponents multiplication division addition and subtraction)
#
# while computing expressions, this sequence is used

# %%
10 - 2 * 4
# Out:
# 2

# %%
(10 - 2) * 4
# Out:
# 32

# %%
((6+4)*2 - 10)/2 - 4
# Out:
# 1.0

# %%
(5 - 1) * ((7 + 1) / (3 - 1))
# ------------------4*(8/2)--------16               ?????????????????????????????????
# Out:
# 16.0

# %%
(5 - 1) * ((7 + 1) / (3 - 1)**2)
# ------------------4 *(8/2**2)------4*2
# Out:
# 8.0

# %%
# paranthesis
# 4 * (8/2**2)

# exponents
# 4* (8/4)
4 * 2
# Out:
# 8

# %% [markdown]
# ### precision

# %%
10/3
# Out:
# 3.3333333333333335

# %%
round(10/3, 3)
# Out:
# 3.333

# %% [markdown]
# ### typecast

# %%
temperature = 30
type(temperature)

# %%
str(temperature)

# %%
str_temp = '30'
type(str_temp)

# %%
int(str_temp)

# %%
int_temp = int(str_temp)
type(int_temp)

# %%
# boolean can be converted to numbers
# True becomes 1, False 0
True + True + False
# Out:
# 2

# %%
2 * False
# Out:
# 0

# %%
5**2  # ** is power
# Out:
# 25

# %%
True ** False
# Out:
# 1

# %%
marks = 95
result = (marks >= 100)
result
# Out:
# False

# %%
result * 2 # boolean is typecast as numeric to execute this calculation
# Out:
# 0

# %%
salary =100000
salary_hike =0.10
new_salary = (salary + (salary*0.1))
print('salary',salary)
print('new_salary',new_salary)
# Out:
# salary 100000
# new_salary 110000.0

# %%
str_temp = '10'
print(type(str_temp))
float_str_temp= float(str_temp)
print(type(float_str_temp))
# Out:
# <class 'str'>
# <class 'float'>

# %%
exp =1000
people_count =3
perstudent = (exp/people_count)
print(perstudent)
remaining =exp%people_count
print(remaining)
# Out:
# 333.3333333333333
# 1

# %%
marks =100
at_least =60
check = (marks >at_least) 
print(check)
# Out:
# True

# %%
strx = 'abc'
print(type(strx))
int_strx =int(strx)
print(int_strx)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 strx = 'abc'
#       2 print(type(strx))
# ----> 3 int_strx =int(strx)
#       4 print(int_strx)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
boolx =True
floatx =10.02
ans=boolx +floatx
print(ans)

# %%
intx =12
floatx =10.02
ans=intx +floatx
print(ans)

type(ans)
# Out:
# 22.02
# float

# %%
int1=12
int2=2
ans=int1*int2
print(type(ans))
ans_div =int1/int2
print(type(ans_div))
# Out:
# <class 'int'>
# <class 'float'>

# %%
str1='abc'
str2= 'def'
print(str1 +str2)
# Out:
# abcdef

# %%
balance ='100'
deposit = 10
new_bal =int(balance) +deposit
print(new_bal)
# Out:
# 110
