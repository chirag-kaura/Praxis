# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from seaborn
df = sns.load_dataset('titanic')

# Display the first few rows
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 1. Histogram - Distribution of 'Age'
plt.figure(figsize=(8, 5))
plt.hist(df['age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Box Plot - 'Fare' distribution by 'Pclass'
plt.figure(figsize=(8, 5))
sns.boxplot(x='pclass', y='fare', data=df) 
plt.title('Box Plot of Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %%
# 3. Scatter Plot - Relationship between 'Age' and 'Fare'
plt.figure(figsize=(8, 5))
plt.scatter(df['age'], df['fare'], alpha=0.5, color='purple')
plt.title('Scatter Plot of Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# 4. Correlation Heatmap - Visualizing correlations between numerical features
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes('number').corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Titanic Features')
plt.show()

# %%
# 5. Pair Plot - Pairwise relationships between selected numerical features
sns.pairplot(df[['age', 'fare', 'pclass']], diag_kind='kde')
plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()

# %%
# 6. Bar Plot - Survival rates by 'Sex'
plt.figure(figsize=(8, 5))
sns.barplot(x='sex', y='survived', data=df, ci=None, palette='pastel')
plt.title('Bar Plot of Survival Rate by Sex')
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.show()
